# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 952us/sample - loss: 241.9290 - y1_output_loss: 119.4234 - y2_output_loss: 120.1938 - y1_output_root_mean_squared_error: 10.9805 - y2_output_root_mean_squared_error: 11.0162 - val_loss: 36.8972 - val_y1_output_loss: 15.7767 - val_y2_output_loss: 21.3780 - val_y1_output_root_mean_squared_error: 3.9897 - val_y2_output_root_mean_squared_error: 4.5803
# Epoch 2/500
# 614/614 [==============================] - 0s 155us/sample - loss: 34.6677 - y1_output_loss: 12.8127 - y2_output_loss: 22.3328 - y1_output_root_mean_squared_error: 3.5686 - y2_output_root_mean_squared_error: 4.6833 - val_loss: 55.3353 - val_y1_output_loss: 12.4239 - val_y2_output_loss: 41.3926 - val_y1_output_root_mean_squared_error: 3.5622 - val_y2_output_root_mean_squared_error: 6.5304
# Epoch 3/500
# 614/614 [==============================] - 0s 160us/sample - loss: 27.2781 - y1_output_loss: 10.4373 - y2_output_loss: 16.6356 - y1_output_root_mean_squared_error: 3.2427 - y2_output_root_mean_squared_error: 4.0943 - val_loss: 21.9548 - val_y1_output_loss: 9.2926 - val_y2_output_loss: 12.9107 - val_y1_output_root_mean_squared_error: 3.0645 - val_y2_output_root_mean_squared_error: 3.5445
# Epoch 4/500
# 614/614 [==============================] - 0s 167us/sample - loss: 23.7694 - y1_output_loss: 9.5444 - y2_output_loss: 14.5258 - y1_output_root_mean_squared_error: 3.0724 - y2_output_root_mean_squared_error: 3.7855 - val_loss: 64.5963 - val_y1_output_loss: 13.6831 - val_y2_output_loss: 49.6194 - val_y1_output_root_mean_squared_error: 3.7379 - val_y2_output_root_mean_squared_error: 7.1151
# Epoch 5/500
# 614/614 [==============================] - 0s 144us/sample - loss: 24.0684 - y1_output_loss: 9.2373 - y2_output_loss: 14.8815 - y1_output_root_mean_squared_error: 3.0428 - y2_output_root_mean_squared_error: 3.8484 - val_loss: 19.9434 - val_y1_output_loss: 8.4434 - val_y2_output_loss: 11.8077 - val_y1_output_root_mean_squared_error: 2.8989 - val_y2_output_root_mean_squared_error: 3.3970
# Epoch 6/500
# 614/614 [==============================] - 0s 142us/sample - loss: 22.3654 - y1_output_loss: 8.8024 - y2_output_loss: 13.4836 - y1_output_root_mean_squared_error: 2.9758 - y2_output_root_mean_squared_error: 3.6756 - val_loss: 23.7577 - val_y1_output_loss: 9.6472 - val_y2_output_loss: 14.7323 - val_y1_output_root_mean_squared_error: 3.1095 - val_y2_output_root_mean_squared_error: 3.7535
# Epoch 7/500
# 614/614 [==============================] - 0s 144us/sample - loss: 20.0739 - y1_output_loss: 8.2507 - y2_output_loss: 11.7288 - y1_output_root_mean_squared_error: 2.8783 - y2_output_root_mean_squared_error: 3.4335 - val_loss: 18.0245 - val_y1_output_loss: 8.0330 - val_y2_output_loss: 10.3552 - val_y1_output_root_mean_squared_error: 2.8378 - val_y2_output_root_mean_squared_error: 3.1578
# Epoch 8/500
# 614/614 [==============================] - 0s 142us/sample - loss: 27.8036 - y1_output_loss: 9.9854 - y2_output_loss: 17.8009 - y1_output_root_mean_squared_error: 3.1606 - y2_output_root_mean_squared_error: 4.2207 - val_loss: 60.0873 - val_y1_output_loss: 14.3564 - val_y2_output_loss: 44.5679 - val_y1_output_root_mean_squared_error: 3.8287 - val_y2_output_root_mean_squared_error: 6.7401
# Epoch 9/500
# 614/614 [==============================] - 0s 151us/sample - loss: 24.6678 - y1_output_loss: 9.0368 - y2_output_loss: 16.0182 - y1_output_root_mean_squared_error: 3.0030 - y2_output_root_mean_squared_error: 3.9560 - val_loss: 30.2516 - val_y1_output_loss: 9.4316 - val_y2_output_loss: 20.2952 - val_y1_output_root_mean_squared_error: 3.0950 - val_y2_output_root_mean_squared_error: 4.5467
# Epoch 10/500
# 614/614 [==============================] - 0s 139us/sample - loss: 22.5388 - y1_output_loss: 8.8671 - y2_output_loss: 13.5542 - y1_output_root_mean_squared_error: 2.9831 - y2_output_root_mean_squared_error: 3.6932 - val_loss: 18.5365 - val_y1_output_loss: 7.7863 - val_y2_output_loss: 11.5722 - val_y1_output_root_mean_squared_error: 2.7826 - val_y2_output_root_mean_squared_error: 3.2853
# Epoch 11/500
# 614/614 [==============================] - 0s 154us/sample - loss: 21.1434 - y1_output_loss: 8.1416 - y2_output_loss: 12.8547 - y1_output_root_mean_squared_error: 2.8629 - y2_output_root_mean_squared_error: 3.5982 - val_loss: 23.9578 - val_y1_output_loss: 7.7862 - val_y2_output_loss: 17.2241 - val_y1_output_root_mean_squared_error: 2.7796 - val_y2_output_root_mean_squared_error: 4.0288
# Epoch 12/500
# 614/614 [==============================] - 0s 142us/sample - loss: 20.4049 - y1_output_loss: 7.8192 - y2_output_loss: 12.5470 - y1_output_root_mean_squared_error: 2.8065 - y2_output_root_mean_squared_error: 3.5396 - val_loss: 21.7751 - val_y1_output_loss: 8.2291 - val_y2_output_loss: 14.5803 - val_y1_output_root_mean_squared_error: 2.8600 - val_y2_output_root_mean_squared_error: 3.6872
# Epoch 13/500
# 614/614 [==============================] - 0s 141us/sample - loss: 27.6687 - y1_output_loss: 9.7335 - y2_output_loss: 17.7480 - y1_output_root_mean_squared_error: 3.1288 - y2_output_root_mean_squared_error: 4.2284 - val_loss: 16.7311 - val_y1_output_loss: 7.4657 - val_y2_output_loss: 9.9489 - val_y1_output_root_mean_squared_error: 2.7154 - val_y2_output_root_mean_squared_error: 3.0590
# Epoch 14/500
# 614/614 [==============================] - 0s 136us/sample - loss: 18.2853 - y1_output_loss: 7.3856 - y2_output_loss: 10.8665 - y1_output_root_mean_squared_error: 2.7210 - y2_output_root_mean_squared_error: 3.2987 - val_loss: 32.5958 - val_y1_output_loss: 9.8229 - val_y2_output_loss: 24.1340 - val_y1_output_root_mean_squared_error: 3.1091 - val_y2_output_root_mean_squared_error: 4.7885
# Epoch 15/500
# 614/614 [==============================] - 0s 142us/sample - loss: 20.4534 - y1_output_loss: 8.2081 - y2_output_loss: 12.5555 - y1_output_root_mean_squared_error: 2.8301 - y2_output_root_mean_squared_error: 3.5276 - val_loss: 48.4822 - val_y1_output_loss: 14.0172 - val_y2_output_loss: 35.5863 - val_y1_output_root_mean_squared_error: 3.7339 - val_y2_output_root_mean_squared_error: 5.8771
# Epoch 16/500
# 614/614 [==============================] - 0s 138us/sample - loss: 20.1376 - y1_output_loss: 7.5742 - y2_output_loss: 12.6956 - y1_output_root_mean_squared_error: 2.7464 - y2_output_root_mean_squared_error: 3.5489 - val_loss: 15.9402 - val_y1_output_loss: 7.2001 - val_y2_output_loss: 9.3115 - val_y1_output_root_mean_squared_error: 2.6819 - val_y2_output_root_mean_squared_error: 2.9576
# Epoch 17/500
# 614/614 [==============================] - 0s 136us/sample - loss: 16.8168 - y1_output_loss: 6.9395 - y2_output_loss: 9.8131 - y1_output_root_mean_squared_error: 2.6433 - y2_output_root_mean_squared_error: 3.1353 - val_loss: 25.2365 - val_y1_output_loss: 7.2236 - val_y2_output_loss: 17.4585 - val_y1_output_root_mean_squared_error: 2.7267 - val_y2_output_root_mean_squared_error: 4.2192
# Epoch 18/500
# 614/614 [==============================] - 0s 138us/sample - loss: 17.2906 - y1_output_loss: 6.9421 - y2_output_loss: 10.3114 - y1_output_root_mean_squared_error: 2.6387 - y2_output_root_mean_squared_error: 3.2137 - val_loss: 18.6416 - val_y1_output_loss: 8.1547 - val_y2_output_loss: 11.2285 - val_y1_output_root_mean_squared_error: 2.8438 - val_y2_output_root_mean_squared_error: 3.2487
# Epoch 19/500
# 614/614 [==============================] - 0s 139us/sample - loss: 15.6773 - y1_output_loss: 6.4741 - y2_output_loss: 9.1781 - y1_output_root_mean_squared_error: 2.5388 - y2_output_root_mean_squared_error: 3.0384 - val_loss: 14.5614 - val_y1_output_loss: 6.4009 - val_y2_output_loss: 8.1931 - val_y1_output_root_mean_squared_error: 2.5551 - val_y2_output_root_mean_squared_error: 2.8342
# Epoch 20/500
# 614/614 [==============================] - 0s 138us/sample - loss: 17.3004 - y1_output_loss: 6.6625 - y2_output_loss: 10.4983 - y1_output_root_mean_squared_error: 2.5886 - y2_output_root_mean_squared_error: 3.2557 - val_loss: 38.1809 - val_y1_output_loss: 13.9336 - val_y2_output_loss: 25.2705 - val_y1_output_root_mean_squared_error: 3.7139 - val_y2_output_root_mean_squared_error: 4.9384
# Epoch 21/500
# 614/614 [==============================] - 0s 147us/sample - loss: 15.3412 - y1_output_loss: 5.9898 - y2_output_loss: 9.3237 - y1_output_root_mean_squared_error: 2.4489 - y2_output_root_mean_squared_error: 3.0568 - val_loss: 16.6157 - val_y1_output_loss: 5.2316 - val_y2_output_loss: 11.8643 - val_y1_output_root_mean_squared_error: 2.2975 - val_y2_output_root_mean_squared_error: 3.3671
# Epoch 22/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.5301 - y1_output_loss: 5.8417 - y2_output_loss: 9.9450 - y1_output_root_mean_squared_error: 2.4096 - y2_output_root_mean_squared_error: 3.1183 - val_loss: 43.0872 - val_y1_output_loss: 10.8070 - val_y2_output_loss: 31.7381 - val_y1_output_root_mean_squared_error: 3.3093 - val_y2_output_root_mean_squared_error: 5.6688
# Epoch 23/500
# 614/614 [==============================] - 0s 138us/sample - loss: 16.6001 - y1_output_loss: 6.4055 - y2_output_loss: 10.2533 - y1_output_root_mean_squared_error: 2.5146 - y2_output_root_mean_squared_error: 3.2057 - val_loss: 21.1549 - val_y1_output_loss: 8.1389 - val_y2_output_loss: 13.8144 - val_y1_output_root_mean_squared_error: 2.8396 - val_y2_output_root_mean_squared_error: 3.6182
# Epoch 24/500
# 614/614 [==============================] - 0s 139us/sample - loss: 15.9052 - y1_output_loss: 5.8339 - y2_output_loss: 9.9861 - y1_output_root_mean_squared_error: 2.4227 - y2_output_root_mean_squared_error: 3.1679 - val_loss: 12.7623 - val_y1_output_loss: 4.7411 - val_y2_output_loss: 7.9854 - val_y1_output_root_mean_squared_error: 2.1965 - val_y2_output_root_mean_squared_error: 2.8174
# Epoch 25/500
# 614/614 [==============================] - 0s 139us/sample - loss: 17.9136 - y1_output_loss: 5.9541 - y2_output_loss: 12.0031 - y1_output_root_mean_squared_error: 2.4393 - y2_output_root_mean_squared_error: 3.4588 - val_loss: 12.1136 - val_y1_output_loss: 5.0825 - val_y2_output_loss: 7.6511 - val_y1_output_root_mean_squared_error: 2.2430 - val_y2_output_root_mean_squared_error: 2.6613
# Epoch 26/500
# 614/614 [==============================] - 0s 139us/sample - loss: 13.6641 - y1_output_loss: 5.1684 - y2_output_loss: 8.4764 - y1_output_root_mean_squared_error: 2.2808 - y2_output_root_mean_squared_error: 2.9089 - val_loss: 16.4230 - val_y1_output_loss: 5.6549 - val_y2_output_loss: 10.4306 - val_y1_output_root_mean_squared_error: 2.4119 - val_y2_output_root_mean_squared_error: 3.2566
# Epoch 27/500
# 614/614 [==============================] - 0s 134us/sample - loss: 13.3519 - y1_output_loss: 4.9335 - y2_output_loss: 8.4147 - y1_output_root_mean_squared_error: 2.2132 - y2_output_root_mean_squared_error: 2.9075 - val_loss: 12.9206 - val_y1_output_loss: 5.7592 - val_y2_output_loss: 7.5304 - val_y1_output_root_mean_squared_error: 2.3993 - val_y2_output_root_mean_squared_error: 2.6766
# Epoch 28/500
# 614/614 [==============================] - 0s 134us/sample - loss: 12.0706 - y1_output_loss: 4.4852 - y2_output_loss: 7.4900 - y1_output_root_mean_squared_error: 2.1267 - y2_output_root_mean_squared_error: 2.7473 - val_loss: 7.8245 - val_y1_output_loss: 2.9250 - val_y2_output_loss: 5.0149 - val_y1_output_root_mean_squared_error: 1.7248 - val_y2_output_root_mean_squared_error: 2.2021
# Epoch 29/500
# 614/614 [==============================] - 0s 151us/sample - loss: 11.4074 - y1_output_loss: 4.0737 - y2_output_loss: 7.2370 - y1_output_root_mean_squared_error: 2.0267 - y2_output_root_mean_squared_error: 2.7019 - val_loss: 9.6764 - val_y1_output_loss: 3.2930 - val_y2_output_loss: 6.2684 - val_y1_output_root_mean_squared_error: 1.8397 - val_y2_output_root_mean_squared_error: 2.5083
# Epoch 30/500
# 614/614 [==============================] - 0s 169us/sample - loss: 10.5695 - y1_output_loss: 3.8877 - y2_output_loss: 6.5976 - y1_output_root_mean_squared_error: 1.9786 - y2_output_root_mean_squared_error: 2.5797 - val_loss: 7.5659 - val_y1_output_loss: 2.7247 - val_y2_output_loss: 4.9115 - val_y1_output_root_mean_squared_error: 1.6659 - val_y2_output_root_mean_squared_error: 2.1887
# Epoch 31/500
# 614/614 [==============================] - 0s 140us/sample - loss: 10.6712 - y1_output_loss: 3.8498 - y2_output_loss: 6.7872 - y1_output_root_mean_squared_error: 1.9666 - y2_output_root_mean_squared_error: 2.6084 - val_loss: 15.4498 - val_y1_output_loss: 5.2690 - val_y2_output_loss: 10.7135 - val_y1_output_root_mean_squared_error: 2.2908 - val_y2_output_root_mean_squared_error: 3.1941
# Epoch 32/500
# 614/614 [==============================] - 0s 136us/sample - loss: 11.0848 - y1_output_loss: 3.9088 - y2_output_loss: 7.0746 - y1_output_root_mean_squared_error: 1.9860 - y2_output_root_mean_squared_error: 2.6722 - val_loss: 9.3262 - val_y1_output_loss: 3.2847 - val_y2_output_loss: 6.1592 - val_y1_output_root_mean_squared_error: 1.8105 - val_y2_output_root_mean_squared_error: 2.4593
# Epoch 33/500
# 614/614 [==============================] - 0s 137us/sample - loss: 11.5630 - y1_output_loss: 3.8269 - y2_output_loss: 7.6988 - y1_output_root_mean_squared_error: 1.9654 - y2_output_root_mean_squared_error: 2.7750 - val_loss: 18.7249 - val_y1_output_loss: 4.8103 - val_y2_output_loss: 13.9943 - val_y1_output_root_mean_squared_error: 2.1811 - val_y2_output_root_mean_squared_error: 3.7374
# Epoch 34/500
# 614/614 [==============================] - 0s 154us/sample - loss: 11.0400 - y1_output_loss: 3.8271 - y2_output_loss: 7.2019 - y1_output_root_mean_squared_error: 1.9540 - y2_output_root_mean_squared_error: 2.6874 - val_loss: 14.4317 - val_y1_output_loss: 5.5576 - val_y2_output_loss: 9.1177 - val_y1_output_root_mean_squared_error: 2.3678 - val_y2_output_root_mean_squared_error: 2.9708
# Epoch 35/500
# 614/614 [==============================] - 0s 136us/sample - loss: 11.8144 - y1_output_loss: 3.7553 - y2_output_loss: 8.0843 - y1_output_root_mean_squared_error: 1.9286 - y2_output_root_mean_squared_error: 2.8452 - val_loss: 21.8380 - val_y1_output_loss: 7.3922 - val_y2_output_loss: 14.7892 - val_y1_output_root_mean_squared_error: 2.7279 - val_y2_output_root_mean_squared_error: 3.7943
# Epoch 36/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.9948 - y1_output_loss: 3.0208 - y2_output_loss: 6.0050 - y1_output_root_mean_squared_error: 1.7397 - y2_output_root_mean_squared_error: 2.4430 - val_loss: 8.2277 - val_y1_output_loss: 2.2403 - val_y2_output_loss: 5.9439 - val_y1_output_root_mean_squared_error: 1.5110 - val_y2_output_root_mean_squared_error: 2.4382
# Epoch 37/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.0653 - y1_output_loss: 3.3029 - y2_output_loss: 5.8236 - y1_output_root_mean_squared_error: 1.8182 - y2_output_root_mean_squared_error: 2.3999 - val_loss: 7.1375 - val_y1_output_loss: 2.6574 - val_y2_output_loss: 4.6412 - val_y1_output_root_mean_squared_error: 1.6260 - val_y2_output_root_mean_squared_error: 2.1198
# Epoch 38/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.3802 - y1_output_loss: 3.0606 - y2_output_loss: 6.2861 - y1_output_root_mean_squared_error: 1.7554 - y2_output_root_mean_squared_error: 2.5097 - val_loss: 12.0067 - val_y1_output_loss: 3.7799 - val_y2_output_loss: 8.4954 - val_y1_output_root_mean_squared_error: 1.9556 - val_y2_output_root_mean_squared_error: 2.8605
# Epoch 39/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.8025 - y1_output_loss: 3.1618 - y2_output_loss: 6.8145 - y1_output_root_mean_squared_error: 1.7607 - y2_output_root_mean_squared_error: 2.5889 - val_loss: 8.6930 - val_y1_output_loss: 2.0718 - val_y2_output_loss: 6.5057 - val_y1_output_root_mean_squared_error: 1.4485 - val_y2_output_root_mean_squared_error: 2.5681
# Epoch 40/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.1445 - y1_output_loss: 3.1247 - y2_output_loss: 6.9535 - y1_output_root_mean_squared_error: 1.7738 - y2_output_root_mean_squared_error: 2.6454 - val_loss: 13.6669 - val_y1_output_loss: 4.9702 - val_y2_output_loss: 8.7127 - val_y1_output_root_mean_squared_error: 2.2525 - val_y2_output_root_mean_squared_error: 2.9314
# Epoch 41/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.9782 - y1_output_loss: 2.6668 - y2_output_loss: 5.3138 - y1_output_root_mean_squared_error: 1.6379 - y2_output_root_mean_squared_error: 2.3012 - val_loss: 6.5352 - val_y1_output_loss: 1.9258 - val_y2_output_loss: 4.6055 - val_y1_output_root_mean_squared_error: 1.4016 - val_y2_output_root_mean_squared_error: 2.1379
# Epoch 42/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.3970 - y1_output_loss: 2.5195 - y2_output_loss: 4.8657 - y1_output_root_mean_squared_error: 1.5822 - y2_output_root_mean_squared_error: 2.2122 - val_loss: 12.0448 - val_y1_output_loss: 3.1882 - val_y2_output_loss: 9.0804 - val_y1_output_root_mean_squared_error: 1.8033 - val_y2_output_root_mean_squared_error: 2.9653
# Epoch 43/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.5614 - y1_output_loss: 2.7424 - y2_output_loss: 5.9059 - y1_output_root_mean_squared_error: 1.6401 - y2_output_root_mean_squared_error: 2.4231 - val_loss: 10.4904 - val_y1_output_loss: 3.5279 - val_y2_output_loss: 7.0770 - val_y1_output_root_mean_squared_error: 1.8984 - val_y2_output_root_mean_squared_error: 2.6242
# Epoch 44/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.3010 - y1_output_loss: 2.6420 - y2_output_loss: 5.5954 - y1_output_root_mean_squared_error: 1.6292 - y2_output_root_mean_squared_error: 2.3763 - val_loss: 6.0648 - val_y1_output_loss: 1.8356 - val_y2_output_loss: 4.2845 - val_y1_output_root_mean_squared_error: 1.3698 - val_y2_output_root_mean_squared_error: 2.0466
# Epoch 45/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.6256 - y1_output_loss: 2.5608 - y2_output_loss: 5.0310 - y1_output_root_mean_squared_error: 1.6027 - y2_output_root_mean_squared_error: 2.2488 - val_loss: 5.7006 - val_y1_output_loss: 1.5725 - val_y2_output_loss: 4.1314 - val_y1_output_root_mean_squared_error: 1.2664 - val_y2_output_root_mean_squared_error: 2.0240
# Epoch 46/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.6115 - y1_output_loss: 2.6076 - y2_output_loss: 5.0046 - y1_output_root_mean_squared_error: 1.6153 - y2_output_root_mean_squared_error: 2.2366 - val_loss: 6.0724 - val_y1_output_loss: 1.8066 - val_y2_output_loss: 4.2568 - val_y1_output_root_mean_squared_error: 1.3589 - val_y2_output_root_mean_squared_error: 2.0557
# Epoch 47/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.9015 - y1_output_loss: 2.2114 - y2_output_loss: 4.6522 - y1_output_root_mean_squared_error: 1.4885 - y2_output_root_mean_squared_error: 2.1647 - val_loss: 9.7459 - val_y1_output_loss: 2.9969 - val_y2_output_loss: 6.8260 - val_y1_output_root_mean_squared_error: 1.7534 - val_y2_output_root_mean_squared_error: 2.5829
# Epoch 48/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.5880 - y1_output_loss: 2.0669 - y2_output_loss: 4.4771 - y1_output_root_mean_squared_error: 1.4436 - y2_output_root_mean_squared_error: 2.1223 - val_loss: 13.4174 - val_y1_output_loss: 3.9851 - val_y2_output_loss: 9.5172 - val_y1_output_root_mean_squared_error: 2.0199 - val_y2_output_root_mean_squared_error: 3.0557
# Epoch 49/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.8867 - y1_output_loss: 2.2100 - y2_output_loss: 4.6923 - y1_output_root_mean_squared_error: 1.4821 - y2_output_root_mean_squared_error: 2.1656 - val_loss: 14.1537 - val_y1_output_loss: 3.3771 - val_y2_output_loss: 10.9098 - val_y1_output_root_mean_squared_error: 1.8601 - val_y2_output_root_mean_squared_error: 3.2701
# Epoch 50/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.3854 - y1_output_loss: 2.3609 - y2_output_loss: 4.9629 - y1_output_root_mean_squared_error: 1.5423 - y2_output_root_mean_squared_error: 2.2376 - val_loss: 6.0162 - val_y1_output_loss: 1.8022 - val_y2_output_loss: 4.2362 - val_y1_output_root_mean_squared_error: 1.3545 - val_y2_output_root_mean_squared_error: 2.0449
# Epoch 51/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.4842 - y1_output_loss: 2.3252 - y2_output_loss: 5.2451 - y1_output_root_mean_squared_error: 1.5278 - y2_output_root_mean_squared_error: 2.2694 - val_loss: 20.0897 - val_y1_output_loss: 3.9847 - val_y2_output_loss: 15.8828 - val_y1_output_root_mean_squared_error: 1.9868 - val_y2_output_root_mean_squared_error: 4.0178
# Epoch 52/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.4699 - y1_output_loss: 2.2596 - y2_output_loss: 6.1905 - y1_output_root_mean_squared_error: 1.5087 - y2_output_root_mean_squared_error: 2.4887 - val_loss: 10.7413 - val_y1_output_loss: 3.5622 - val_y2_output_loss: 7.1431 - val_y1_output_root_mean_squared_error: 1.9156 - val_y2_output_root_mean_squared_error: 2.6593
# Epoch 53/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.6607 - y1_output_loss: 2.4197 - y2_output_loss: 5.2188 - y1_output_root_mean_squared_error: 1.5526 - y2_output_root_mean_squared_error: 2.2913 - val_loss: 6.9396 - val_y1_output_loss: 1.4669 - val_y2_output_loss: 5.3407 - val_y1_output_root_mean_squared_error: 1.2265 - val_y2_output_root_mean_squared_error: 2.3314
# Epoch 54/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.4700 - y1_output_loss: 2.5182 - y2_output_loss: 5.9641 - y1_output_root_mean_squared_error: 1.5890 - y2_output_root_mean_squared_error: 2.4382 - val_loss: 5.5621 - val_y1_output_loss: 1.5316 - val_y2_output_loss: 4.0531 - val_y1_output_root_mean_squared_error: 1.2551 - val_y2_output_root_mean_squared_error: 1.9967
# Epoch 55/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.3995 - y1_output_loss: 2.0084 - y2_output_loss: 4.4629 - y1_output_root_mean_squared_error: 1.4112 - y2_output_root_mean_squared_error: 2.0995 - val_loss: 15.8737 - val_y1_output_loss: 4.0758 - val_y2_output_loss: 11.7792 - val_y1_output_root_mean_squared_error: 2.0016 - val_y2_output_root_mean_squared_error: 3.4449
# Epoch 56/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.1287 - y1_output_loss: 2.0546 - y2_output_loss: 5.1148 - y1_output_root_mean_squared_error: 1.4141 - y2_output_root_mean_squared_error: 2.2647 - val_loss: 5.3831 - val_y1_output_loss: 1.6916 - val_y2_output_loss: 3.7902 - val_y1_output_root_mean_squared_error: 1.3025 - val_y2_output_root_mean_squared_error: 1.9200
# Epoch 57/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.6966 - y1_output_loss: 2.3285 - y2_output_loss: 5.4020 - y1_output_root_mean_squared_error: 1.5197 - y2_output_root_mean_squared_error: 2.3210 - val_loss: 18.4434 - val_y1_output_loss: 4.1085 - val_y2_output_loss: 14.6499 - val_y1_output_root_mean_squared_error: 2.0438 - val_y2_output_root_mean_squared_error: 3.7771
# Epoch 58/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.6302 - y1_output_loss: 1.6941 - y2_output_loss: 3.9148 - y1_output_root_mean_squared_error: 1.2981 - y2_output_root_mean_squared_error: 1.9863 - val_loss: 5.4335 - val_y1_output_loss: 1.6606 - val_y2_output_loss: 3.7592 - val_y1_output_root_mean_squared_error: 1.3084 - val_y2_output_root_mean_squared_error: 1.9291
# Epoch 59/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.6997 - y1_output_loss: 2.0144 - y2_output_loss: 4.6294 - y1_output_root_mean_squared_error: 1.4244 - y2_output_root_mean_squared_error: 2.1612 - val_loss: 5.6493 - val_y1_output_loss: 1.5677 - val_y2_output_loss: 4.2007 - val_y1_output_root_mean_squared_error: 1.2661 - val_y2_output_root_mean_squared_error: 2.0115
# Epoch 60/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.2217 - y1_output_loss: 1.8582 - y2_output_loss: 4.3710 - y1_output_root_mean_squared_error: 1.3692 - y2_output_root_mean_squared_error: 2.0849 - val_loss: 19.7423 - val_y1_output_loss: 3.2447 - val_y2_output_loss: 16.1157 - val_y1_output_root_mean_squared_error: 1.8020 - val_y2_output_root_mean_squared_error: 4.0614
# Epoch 61/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.5252 - y1_output_loss: 2.0028 - y2_output_loss: 4.4856 - y1_output_root_mean_squared_error: 1.4192 - y2_output_root_mean_squared_error: 2.1239 - val_loss: 7.2493 - val_y1_output_loss: 1.3597 - val_y2_output_loss: 6.0757 - val_y1_output_root_mean_squared_error: 1.1733 - val_y2_output_root_mean_squared_error: 2.4233
# Epoch 62/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.6013 - y1_output_loss: 1.8672 - y2_output_loss: 4.6767 - y1_output_root_mean_squared_error: 1.3718 - y2_output_root_mean_squared_error: 2.1724 - val_loss: 10.1017 - val_y1_output_loss: 3.0080 - val_y2_output_loss: 7.2835 - val_y1_output_root_mean_squared_error: 1.7508 - val_y2_output_root_mean_squared_error: 2.6526
# Epoch 63/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.3784 - y1_output_loss: 1.6230 - y2_output_loss: 3.7811 - y1_output_root_mean_squared_error: 1.2710 - y2_output_root_mean_squared_error: 1.9398 - val_loss: 7.6685 - val_y1_output_loss: 2.3335 - val_y2_output_loss: 5.2665 - val_y1_output_root_mean_squared_error: 1.5535 - val_y2_output_root_mean_squared_error: 2.2924
# Epoch 64/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.2491 - y1_output_loss: 1.5637 - y2_output_loss: 3.6506 - y1_output_root_mean_squared_error: 1.2547 - y2_output_root_mean_squared_error: 1.9170 - val_loss: 4.7604 - val_y1_output_loss: 1.0334 - val_y2_output_loss: 3.6888 - val_y1_output_root_mean_squared_error: 1.0301 - val_y2_output_root_mean_squared_error: 1.9233
# Epoch 65/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.8458 - y1_output_loss: 1.3546 - y2_output_loss: 3.4489 - y1_output_root_mean_squared_error: 1.1691 - y2_output_root_mean_squared_error: 1.8652 - val_loss: 8.1407 - val_y1_output_loss: 2.3047 - val_y2_output_loss: 5.9740 - val_y1_output_root_mean_squared_error: 1.5368 - val_y2_output_root_mean_squared_error: 2.4039
# Epoch 66/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.8195 - y1_output_loss: 1.5468 - y2_output_loss: 4.3522 - y1_output_root_mean_squared_error: 1.2332 - y2_output_root_mean_squared_error: 2.0733 - val_loss: 40.2566 - val_y1_output_loss: 11.9414 - val_y2_output_loss: 28.4771 - val_y1_output_root_mean_squared_error: 3.4815 - val_y2_output_root_mean_squared_error: 5.3043
# Epoch 67/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.2977 - y1_output_loss: 2.7592 - y2_output_loss: 6.4848 - y1_output_root_mean_squared_error: 1.6588 - y2_output_root_mean_squared_error: 2.5586 - val_loss: 8.1364 - val_y1_output_loss: 3.0202 - val_y2_output_loss: 5.2610 - val_y1_output_root_mean_squared_error: 1.7321 - val_y2_output_root_mean_squared_error: 2.2663
# Epoch 68/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.2751 - y1_output_loss: 1.4399 - y2_output_loss: 3.8436 - y1_output_root_mean_squared_error: 1.2012 - y2_output_root_mean_squared_error: 1.9576 - val_loss: 6.7118 - val_y1_output_loss: 1.6652 - val_y2_output_loss: 5.1944 - val_y1_output_root_mean_squared_error: 1.3083 - val_y2_output_root_mean_squared_error: 2.2361
# Epoch 69/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.3087 - y1_output_loss: 1.0081 - y2_output_loss: 3.2920 - y1_output_root_mean_squared_error: 0.9974 - y2_output_root_mean_squared_error: 1.8204 - val_loss: 6.7305 - val_y1_output_loss: 1.9662 - val_y2_output_loss: 5.0245 - val_y1_output_root_mean_squared_error: 1.4101 - val_y2_output_root_mean_squared_error: 2.1776
# Epoch 70/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.3658 - y1_output_loss: 1.1955 - y2_output_loss: 3.1606 - y1_output_root_mean_squared_error: 1.0930 - y2_output_root_mean_squared_error: 1.7808 - val_loss: 4.8152 - val_y1_output_loss: 1.3292 - val_y2_output_loss: 3.4842 - val_y1_output_root_mean_squared_error: 1.1602 - val_y2_output_root_mean_squared_error: 1.8626
# Epoch 71/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.2637 - y1_output_loss: 1.1194 - y2_output_loss: 3.1405 - y1_output_root_mean_squared_error: 1.0605 - y2_output_root_mean_squared_error: 1.7717 - val_loss: 9.9867 - val_y1_output_loss: 1.3524 - val_y2_output_loss: 8.9148 - val_y1_output_root_mean_squared_error: 1.1794 - val_y2_output_root_mean_squared_error: 2.9318
# Epoch 72/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.6789 - y1_output_loss: 1.2756 - y2_output_loss: 3.3777 - y1_output_root_mean_squared_error: 1.1327 - y2_output_root_mean_squared_error: 1.8428 - val_loss: 8.4577 - val_y1_output_loss: 2.1217 - val_y2_output_loss: 6.1506 - val_y1_output_root_mean_squared_error: 1.4695 - val_y2_output_root_mean_squared_error: 2.5096
# Epoch 73/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.1434 - y1_output_loss: 1.2194 - y2_output_loss: 3.9326 - y1_output_root_mean_squared_error: 1.0998 - y2_output_root_mean_squared_error: 1.9834 - val_loss: 6.0851 - val_y1_output_loss: 1.4437 - val_y2_output_loss: 4.6229 - val_y1_output_root_mean_squared_error: 1.1977 - val_y2_output_root_mean_squared_error: 2.1565
# Epoch 74/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.2496 - y1_output_loss: 2.0016 - y2_output_loss: 5.2177 - y1_output_root_mean_squared_error: 1.4126 - y2_output_root_mean_squared_error: 2.2922 - val_loss: 7.4393 - val_y1_output_loss: 2.3600 - val_y2_output_loss: 5.3482 - val_y1_output_root_mean_squared_error: 1.5396 - val_y2_output_root_mean_squared_error: 2.2514
# Epoch 75/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.7874 - y1_output_loss: 0.8132 - y2_output_loss: 3.0091 - y1_output_root_mean_squared_error: 0.8997 - y2_output_root_mean_squared_error: 1.7257 - val_loss: 4.9668 - val_y1_output_loss: 0.7482 - val_y2_output_loss: 4.1000 - val_y1_output_root_mean_squared_error: 0.8680 - val_y2_output_root_mean_squared_error: 2.0526
# Epoch 76/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.6651 - y1_output_loss: 1.2497 - y2_output_loss: 4.3800 - y1_output_root_mean_squared_error: 1.1224 - y2_output_root_mean_squared_error: 2.0989 - val_loss: 5.6832 - val_y1_output_loss: 0.5397 - val_y2_output_loss: 5.0110 - val_y1_output_root_mean_squared_error: 0.7423 - val_y2_output_root_mean_squared_error: 2.2654
# Epoch 77/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.4316 - y1_output_loss: 0.7454 - y2_output_loss: 2.6666 - y1_output_root_mean_squared_error: 0.8656 - y2_output_root_mean_squared_error: 1.6378 - val_loss: 4.1689 - val_y1_output_loss: 0.8891 - val_y2_output_loss: 3.2882 - val_y1_output_root_mean_squared_error: 0.9591 - val_y2_output_root_mean_squared_error: 1.8025
# Epoch 78/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.4321 - y1_output_loss: 0.7423 - y2_output_loss: 2.6811 - y1_output_root_mean_squared_error: 0.8563 - y2_output_root_mean_squared_error: 1.6428 - val_loss: 3.9527 - val_y1_output_loss: 0.8807 - val_y2_output_loss: 3.1825 - val_y1_output_root_mean_squared_error: 0.9521 - val_y2_output_root_mean_squared_error: 1.7453
# Epoch 79/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.4310 - y1_output_loss: 0.7150 - y2_output_loss: 2.6990 - y1_output_root_mean_squared_error: 0.8456 - y2_output_root_mean_squared_error: 1.6480 - val_loss: 4.3902 - val_y1_output_loss: 0.5695 - val_y2_output_loss: 4.0599 - val_y1_output_root_mean_squared_error: 0.7662 - val_y2_output_root_mean_squared_error: 1.9502
# Epoch 80/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.3804 - y1_output_loss: 0.7108 - y2_output_loss: 2.6676 - y1_output_root_mean_squared_error: 0.8411 - y2_output_root_mean_squared_error: 1.6349 - val_loss: 7.3816 - val_y1_output_loss: 1.4466 - val_y2_output_loss: 5.7345 - val_y1_output_root_mean_squared_error: 1.2236 - val_y2_output_root_mean_squared_error: 2.4258
# Epoch 81/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.5777 - y1_output_loss: 1.0932 - y2_output_loss: 3.4961 - y1_output_root_mean_squared_error: 1.0487 - y2_output_root_mean_squared_error: 1.8649 - val_loss: 10.5980 - val_y1_output_loss: 1.8004 - val_y2_output_loss: 8.9150 - val_y1_output_root_mean_squared_error: 1.3663 - val_y2_output_root_mean_squared_error: 2.9549
# Epoch 82/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.0149 - y1_output_loss: 0.5451 - y2_output_loss: 2.4560 - y1_output_root_mean_squared_error: 0.7379 - y2_output_root_mean_squared_error: 1.5718 - val_loss: 3.7160 - val_y1_output_loss: 0.7332 - val_y2_output_loss: 3.1463 - val_y1_output_root_mean_squared_error: 0.8655 - val_y2_output_root_mean_squared_error: 1.7225
# Epoch 83/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.4440 - y1_output_loss: 0.7062 - y2_output_loss: 2.7438 - y1_output_root_mean_squared_error: 0.8434 - y2_output_root_mean_squared_error: 1.6531 - val_loss: 5.2977 - val_y1_output_loss: 0.5640 - val_y2_output_loss: 5.0285 - val_y1_output_root_mean_squared_error: 0.7611 - val_y2_output_root_mean_squared_error: 2.1722
# Epoch 84/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.9962 - y1_output_loss: 1.1951 - y2_output_loss: 3.8364 - y1_output_root_mean_squared_error: 1.0819 - y2_output_root_mean_squared_error: 1.9560 - val_loss: 5.3452 - val_y1_output_loss: 1.3313 - val_y2_output_loss: 3.9610 - val_y1_output_root_mean_squared_error: 1.1650 - val_y2_output_root_mean_squared_error: 1.9970
# Epoch 85/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.3694 - y1_output_loss: 0.8121 - y2_output_loss: 2.5771 - y1_output_root_mean_squared_error: 0.9024 - y2_output_root_mean_squared_error: 1.5984 - val_loss: 22.5191 - val_y1_output_loss: 4.1699 - val_y2_output_loss: 17.7528 - val_y1_output_root_mean_squared_error: 2.0658 - val_y2_output_root_mean_squared_error: 4.2722
# Epoch 86/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.5929 - y1_output_loss: 1.1983 - y2_output_loss: 3.3538 - y1_output_root_mean_squared_error: 1.0995 - y2_output_root_mean_squared_error: 1.8395 - val_loss: 3.5025 - val_y1_output_loss: 0.5083 - val_y2_output_loss: 2.9896 - val_y1_output_root_mean_squared_error: 0.7244 - val_y2_output_root_mean_squared_error: 1.7256
# Epoch 87/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.5786 - y1_output_loss: 1.4052 - y2_output_loss: 4.1417 - y1_output_root_mean_squared_error: 1.1885 - y2_output_root_mean_squared_error: 2.0411 - val_loss: 3.7935 - val_y1_output_loss: 0.8660 - val_y2_output_loss: 3.0170 - val_y1_output_root_mean_squared_error: 0.9442 - val_y2_output_root_mean_squared_error: 1.7035
# Epoch 88/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.6568 - y1_output_loss: 1.0938 - y2_output_loss: 3.7452 - y1_output_root_mean_squared_error: 1.0426 - y2_output_root_mean_squared_error: 1.8894 - val_loss: 57.0476 - val_y1_output_loss: 14.0572 - val_y2_output_loss: 43.1833 - val_y1_output_root_mean_squared_error: 3.7863 - val_y2_output_root_mean_squared_error: 6.5354
# Epoch 89/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.3733 - y1_output_loss: 1.2718 - y2_output_loss: 5.0574 - y1_output_root_mean_squared_error: 1.1299 - y2_output_root_mean_squared_error: 2.2576 - val_loss: 4.8239 - val_y1_output_loss: 0.7477 - val_y2_output_loss: 4.2538 - val_y1_output_root_mean_squared_error: 0.8797 - val_y2_output_root_mean_squared_error: 2.0125
# Epoch 90/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.0581 - y1_output_loss: 0.5816 - y2_output_loss: 2.4706 - y1_output_root_mean_squared_error: 0.7651 - y2_output_root_mean_squared_error: 1.5725 - val_loss: 3.1990 - val_y1_output_loss: 0.5294 - val_y2_output_loss: 2.7253 - val_y1_output_root_mean_squared_error: 0.7359 - val_y2_output_root_mean_squared_error: 1.6302
# Epoch 91/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.7836 - y1_output_loss: 0.5121 - y2_output_loss: 2.2462 - y1_output_root_mean_squared_error: 0.7185 - y2_output_root_mean_squared_error: 1.5058 - val_loss: 3.1987 - val_y1_output_loss: 0.5676 - val_y2_output_loss: 2.7168 - val_y1_output_root_mean_squared_error: 0.7652 - val_y2_output_root_mean_squared_error: 1.6165
# Epoch 92/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.0834 - y1_output_loss: 0.6651 - y2_output_loss: 2.4478 - y1_output_root_mean_squared_error: 0.8083 - y2_output_root_mean_squared_error: 1.5589 - val_loss: 4.9055 - val_y1_output_loss: 0.7084 - val_y2_output_loss: 4.1103 - val_y1_output_root_mean_squared_error: 0.8518 - val_y2_output_root_mean_squared_error: 2.0445
# Epoch 93/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.9735 - y1_output_loss: 1.1673 - y2_output_loss: 3.7911 - y1_output_root_mean_squared_error: 1.0841 - y2_output_root_mean_squared_error: 1.9489 - val_loss: 3.5305 - val_y1_output_loss: 0.7006 - val_y2_output_loss: 2.9983 - val_y1_output_root_mean_squared_error: 0.8444 - val_y2_output_root_mean_squared_error: 1.6786
# Epoch 94/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.1729 - y1_output_loss: 0.6595 - y2_output_loss: 2.5125 - y1_output_root_mean_squared_error: 0.8135 - y2_output_root_mean_squared_error: 1.5847 - val_loss: 4.8108 - val_y1_output_loss: 0.9463 - val_y2_output_loss: 4.0430 - val_y1_output_root_mean_squared_error: 0.9850 - val_y2_output_root_mean_squared_error: 1.9598
# Epoch 95/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.8808 - y1_output_loss: 0.6117 - y2_output_loss: 2.3114 - y1_output_root_mean_squared_error: 0.7739 - y2_output_root_mean_squared_error: 1.5106 - val_loss: 5.7572 - val_y1_output_loss: 2.2034 - val_y2_output_loss: 3.4682 - val_y1_output_root_mean_squared_error: 1.5112 - val_y2_output_root_mean_squared_error: 1.8637
# Epoch 96/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.4683 - y1_output_loss: 1.5399 - y2_output_loss: 4.8804 - y1_output_root_mean_squared_error: 1.2456 - y2_output_root_mean_squared_error: 2.2174 - val_loss: 3.4638 - val_y1_output_loss: 0.4670 - val_y2_output_loss: 2.9673 - val_y1_output_root_mean_squared_error: 0.6926 - val_y2_output_root_mean_squared_error: 1.7275
# Epoch 97/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.8481 - y1_output_loss: 0.5012 - y2_output_loss: 2.5977 - y1_output_root_mean_squared_error: 0.7074 - y2_output_root_mean_squared_error: 1.5322 - val_loss: 61.2395 - val_y1_output_loss: 11.3212 - val_y2_output_loss: 50.9630 - val_y1_output_root_mean_squared_error: 3.3676 - val_y2_output_root_mean_squared_error: 7.0639
# Epoch 98/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.8333 - y1_output_loss: 1.0713 - y2_output_loss: 3.7990 - y1_output_root_mean_squared_error: 1.0376 - y2_output_root_mean_squared_error: 1.9382 - val_loss: 21.5215 - val_y1_output_loss: 3.0044 - val_y2_output_loss: 17.9718 - val_y1_output_root_mean_squared_error: 1.7440 - val_y2_output_root_mean_squared_error: 4.2988
# Epoch 99/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.0659 - y1_output_loss: 0.5249 - y2_output_loss: 2.5242 - y1_output_root_mean_squared_error: 0.7260 - y2_output_root_mean_squared_error: 1.5934 - val_loss: 3.4550 - val_y1_output_loss: 0.5919 - val_y2_output_loss: 2.9428 - val_y1_output_root_mean_squared_error: 0.7811 - val_y2_output_root_mean_squared_error: 1.6867
# Epoch 100/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.1149 - y1_output_loss: 0.6632 - y2_output_loss: 2.4397 - y1_output_root_mean_squared_error: 0.8172 - y2_output_root_mean_squared_error: 1.5643 - val_loss: 3.3409 - val_y1_output_loss: 0.4651 - val_y2_output_loss: 2.9799 - val_y1_output_root_mean_squared_error: 0.6901 - val_y2_output_root_mean_squared_error: 1.6925
# Epoch 101/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.7947 - y1_output_loss: 0.5651 - y2_output_loss: 2.2420 - y1_output_root_mean_squared_error: 0.7466 - y2_output_root_mean_squared_error: 1.4958 - val_loss: 8.3911 - val_y1_output_loss: 2.0443 - val_y2_output_loss: 6.1042 - val_y1_output_root_mean_squared_error: 1.4548 - val_y2_output_root_mean_squared_error: 2.5049
# Epoch 102/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.4554 - y1_output_loss: 0.5145 - y2_output_loss: 1.9335 - y1_output_root_mean_squared_error: 0.7171 - y2_output_root_mean_squared_error: 1.3933 - val_loss: 3.7406 - val_y1_output_loss: 0.8698 - val_y2_output_loss: 2.9173 - val_y1_output_root_mean_squared_error: 0.9447 - val_y2_output_root_mean_squared_error: 1.6876
# Epoch 103/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.9116 - y1_output_loss: 1.0000 - y2_output_loss: 2.8778 - y1_output_root_mean_squared_error: 1.0037 - y2_output_root_mean_squared_error: 1.7042 - val_loss: 2.8307 - val_y1_output_loss: 0.4369 - val_y2_output_loss: 2.4536 - val_y1_output_root_mean_squared_error: 0.6684 - val_y2_output_root_mean_squared_error: 1.5440
# Epoch 104/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.7079 - y1_output_loss: 0.5380 - y2_output_loss: 2.1897 - y1_output_root_mean_squared_error: 0.7313 - y2_output_root_mean_squared_error: 1.4741 - val_loss: 5.5372 - val_y1_output_loss: 0.7151 - val_y2_output_loss: 5.0199 - val_y1_output_root_mean_squared_error: 0.8599 - val_y2_output_root_mean_squared_error: 2.1904
# Epoch 105/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.6362 - y1_output_loss: 0.7620 - y2_output_loss: 2.8566 - y1_output_root_mean_squared_error: 0.8758 - y2_output_root_mean_squared_error: 1.6939 - val_loss: 4.7526 - val_y1_output_loss: 0.6089 - val_y2_output_loss: 4.3740 - val_y1_output_root_mean_squared_error: 0.7928 - val_y2_output_root_mean_squared_error: 2.0308
# Epoch 106/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.8589 - y1_output_loss: 0.6367 - y2_output_loss: 2.1974 - y1_output_root_mean_squared_error: 0.8015 - y2_output_root_mean_squared_error: 1.4888 - val_loss: 2.7702 - val_y1_output_loss: 0.4539 - val_y2_output_loss: 2.4080 - val_y1_output_root_mean_squared_error: 0.6844 - val_y2_output_root_mean_squared_error: 1.5172
# Epoch 107/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.4137 - y1_output_loss: 1.1012 - y2_output_loss: 3.2807 - y1_output_root_mean_squared_error: 1.0523 - y2_output_root_mean_squared_error: 1.8183 - val_loss: 6.6149 - val_y1_output_loss: 2.4324 - val_y2_output_loss: 4.1082 - val_y1_output_root_mean_squared_error: 1.5836 - val_y2_output_root_mean_squared_error: 2.0266
# Epoch 108/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.7891 - y1_output_loss: 0.5808 - y2_output_loss: 2.1863 - y1_output_root_mean_squared_error: 0.7646 - y2_output_root_mean_squared_error: 1.4848 - val_loss: 3.8803 - val_y1_output_loss: 0.8764 - val_y2_output_loss: 2.9819 - val_y1_output_root_mean_squared_error: 0.9520 - val_y2_output_root_mean_squared_error: 1.7245
# Epoch 109/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.1458 - y1_output_loss: 0.6706 - y2_output_loss: 2.4791 - y1_output_root_mean_squared_error: 0.8113 - y2_output_root_mean_squared_error: 1.5772 - val_loss: 12.9374 - val_y1_output_loss: 4.3391 - val_y2_output_loss: 8.1598 - val_y1_output_root_mean_squared_error: 2.1154 - val_y2_output_root_mean_squared_error: 2.9090
# Epoch 110/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.1493 - y1_output_loss: 0.9034 - y2_output_loss: 3.2368 - y1_output_root_mean_squared_error: 0.9537 - y2_output_root_mean_squared_error: 1.8000 - val_loss: 13.3964 - val_y1_output_loss: 3.1621 - val_y2_output_loss: 10.3574 - val_y1_output_root_mean_squared_error: 1.8040 - val_y2_output_root_mean_squared_error: 3.1847
# Epoch 111/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.5235 - y1_output_loss: 0.9370 - y2_output_loss: 2.9925 - y1_output_root_mean_squared_error: 0.8925 - y2_output_root_mean_squared_error: 1.6513 - val_loss: 95.4290 - val_y1_output_loss: 29.4642 - val_y2_output_loss: 62.9348 - val_y1_output_root_mean_squared_error: 5.5161 - val_y2_output_root_mean_squared_error: 8.0623
# Epoch 112/500
# 614/614 [==============================] - 0s 132us/sample - loss: 26.8965 - y1_output_loss: 9.9705 - y2_output_loss: 16.6681 - y1_output_root_mean_squared_error: 3.1728 - y2_output_root_mean_squared_error: 4.1024 - val_loss: 3.0230 - val_y1_output_loss: 0.6581 - val_y2_output_loss: 2.4670 - val_y1_output_root_mean_squared_error: 0.8235 - val_y2_output_root_mean_squared_error: 1.5313
# Epoch 113/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.3056 - y1_output_loss: 1.0569 - y2_output_loss: 3.2348 - y1_output_root_mean_squared_error: 1.0319 - y2_output_root_mean_squared_error: 1.8003 - val_loss: 4.2013 - val_y1_output_loss: 0.7901 - val_y2_output_loss: 3.3398 - val_y1_output_root_mean_squared_error: 0.9014 - val_y2_output_root_mean_squared_error: 1.8409
# Epoch 114/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.6735 - y1_output_loss: 0.5720 - y2_output_loss: 2.1017 - y1_output_root_mean_squared_error: 0.7591 - y2_output_root_mean_squared_error: 1.4482 - val_loss: 2.5774 - val_y1_output_loss: 0.4419 - val_y2_output_loss: 2.1756 - val_y1_output_root_mean_squared_error: 0.6745 - val_y2_output_root_mean_squared_error: 1.4569
# Epoch 115/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.0802 - y1_output_loss: 0.6061 - y2_output_loss: 2.4611 - y1_output_root_mean_squared_error: 0.7806 - y2_output_root_mean_squared_error: 1.5719 - val_loss: 3.3548 - val_y1_output_loss: 0.7392 - val_y2_output_loss: 2.5945 - val_y1_output_root_mean_squared_error: 0.8710 - val_y2_output_root_mean_squared_error: 1.6113
# Epoch 116/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.6034 - y1_output_loss: 0.4494 - y2_output_loss: 2.1313 - y1_output_root_mean_squared_error: 0.6732 - y2_output_root_mean_squared_error: 1.4663 - val_loss: 3.6051 - val_y1_output_loss: 0.7677 - val_y2_output_loss: 2.8109 - val_y1_output_root_mean_squared_error: 0.8813 - val_y2_output_root_mean_squared_error: 1.6818
# Epoch 117/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.9795 - y1_output_loss: 0.6800 - y2_output_loss: 3.3128 - y1_output_root_mean_squared_error: 0.8252 - y2_output_root_mean_squared_error: 1.8162 - val_loss: 3.0907 - val_y1_output_loss: 0.7246 - val_y2_output_loss: 2.4242 - val_y1_output_root_mean_squared_error: 0.8636 - val_y2_output_root_mean_squared_error: 1.5313
# Epoch 118/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.8201 - y1_output_loss: 0.6035 - y2_output_loss: 2.2093 - y1_output_root_mean_squared_error: 0.7771 - y2_output_root_mean_squared_error: 1.4887 - val_loss: 2.6015 - val_y1_output_loss: 0.3801 - val_y2_output_loss: 2.2282 - val_y1_output_root_mean_squared_error: 0.6261 - val_y2_output_root_mean_squared_error: 1.4864
# Epoch 119/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.9703 - y1_output_loss: 0.5962 - y2_output_loss: 2.4861 - y1_output_root_mean_squared_error: 0.7528 - y2_output_root_mean_squared_error: 1.5503 - val_loss: 15.0012 - val_y1_output_loss: 3.9665 - val_y2_output_loss: 11.5646 - val_y1_output_root_mean_squared_error: 1.9769 - val_y2_output_root_mean_squared_error: 3.3306
# Epoch 120/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.3441 - y1_output_loss: 0.4695 - y2_output_loss: 1.8887 - y1_output_root_mean_squared_error: 0.6835 - y2_output_root_mean_squared_error: 1.3700 - val_loss: 7.0211 - val_y1_output_loss: 0.5480 - val_y2_output_loss: 6.7465 - val_y1_output_root_mean_squared_error: 0.7486 - val_y2_output_root_mean_squared_error: 2.5418
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.6058 - y1_output_loss: 0.1417 - y2_output_loss: 0.4601 - y1_output_root_mean_squared_error: 0.3773 - y2_output_root_mean_squared_error: 0.6808 - val_loss: 0.8529 - val_y1_output_loss: 0.2112 - val_y2_output_loss: 0.6243 - val_y1_output_root_mean_squared_error: 0.4650 - val_y2_output_root_mean_squared_error: 0.7979
# Epoch 462/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3831 - y1_output_loss: 0.1110 - y2_output_loss: 0.2695 - y1_output_root_mean_squared_error: 0.3343 - y2_output_root_mean_squared_error: 0.5209 - val_loss: 1.0539 - val_y1_output_loss: 0.2210 - val_y2_output_loss: 0.7967 - val_y1_output_root_mean_squared_error: 0.4782 - val_y2_output_root_mean_squared_error: 0.9084
# Epoch 463/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4837 - y1_output_loss: 0.1388 - y2_output_loss: 0.3412 - y1_output_root_mean_squared_error: 0.3736 - y2_output_root_mean_squared_error: 0.5867 - val_loss: 1.0387 - val_y1_output_loss: 0.3131 - val_y2_output_loss: 0.7074 - val_y1_output_root_mean_squared_error: 0.5656 - val_y2_output_root_mean_squared_error: 0.8478
# Epoch 464/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3826 - y1_output_loss: 0.1065 - y2_output_loss: 0.2759 - y1_output_root_mean_squared_error: 0.3268 - y2_output_root_mean_squared_error: 0.5252 - val_loss: 0.7945 - val_y1_output_loss: 0.1958 - val_y2_output_loss: 0.5821 - val_y1_output_root_mean_squared_error: 0.4475 - val_y2_output_root_mean_squared_error: 0.7709
# Epoch 465/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.7148 - y1_output_loss: 0.1711 - y2_output_loss: 0.5444 - y1_output_root_mean_squared_error: 0.4141 - y2_output_root_mean_squared_error: 0.7371 - val_loss: 1.1718 - val_y1_output_loss: 0.2894 - val_y2_output_loss: 0.9116 - val_y1_output_root_mean_squared_error: 0.5342 - val_y2_output_root_mean_squared_error: 0.9415
# Epoch 466/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4290 - y1_output_loss: 0.1190 - y2_output_loss: 0.3104 - y1_output_root_mean_squared_error: 0.3432 - y2_output_root_mean_squared_error: 0.5578 - val_loss: 0.8380 - val_y1_output_loss: 0.2752 - val_y2_output_loss: 0.5536 - val_y1_output_root_mean_squared_error: 0.5258 - val_y2_output_root_mean_squared_error: 0.7493
# Epoch 467/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3938 - y1_output_loss: 0.1207 - y2_output_loss: 0.2726 - y1_output_root_mean_squared_error: 0.3470 - y2_output_root_mean_squared_error: 0.5229 - val_loss: 0.7642 - val_y1_output_loss: 0.1941 - val_y2_output_loss: 0.5515 - val_y1_output_root_mean_squared_error: 0.4471 - val_y2_output_root_mean_squared_error: 0.7512
# Epoch 468/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3933 - y1_output_loss: 0.1135 - y2_output_loss: 0.2813 - y1_output_root_mean_squared_error: 0.3363 - y2_output_root_mean_squared_error: 0.5293 - val_loss: 0.9885 - val_y1_output_loss: 0.2095 - val_y2_output_loss: 0.7858 - val_y1_output_root_mean_squared_error: 0.4601 - val_y2_output_root_mean_squared_error: 0.8814
# Epoch 469/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3923 - y1_output_loss: 0.1111 - y2_output_loss: 0.2795 - y1_output_root_mean_squared_error: 0.3349 - y2_output_root_mean_squared_error: 0.5293 - val_loss: 0.8766 - val_y1_output_loss: 0.1995 - val_y2_output_loss: 0.6761 - val_y1_output_root_mean_squared_error: 0.4518 - val_y2_output_root_mean_squared_error: 0.8200
# Epoch 470/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4776 - y1_output_loss: 0.1221 - y2_output_loss: 0.3527 - y1_output_root_mean_squared_error: 0.3499 - y2_output_root_mean_squared_error: 0.5960 - val_loss: 0.8898 - val_y1_output_loss: 0.2268 - val_y2_output_loss: 0.6496 - val_y1_output_root_mean_squared_error: 0.4840 - val_y2_output_root_mean_squared_error: 0.8097
# Epoch 471/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4562 - y1_output_loss: 0.1305 - y2_output_loss: 0.3311 - y1_output_root_mean_squared_error: 0.3606 - y2_output_root_mean_squared_error: 0.5711 - val_loss: 1.0554 - val_y1_output_loss: 0.2710 - val_y2_output_loss: 0.7520 - val_y1_output_root_mean_squared_error: 0.5278 - val_y2_output_root_mean_squared_error: 0.8814
# Epoch 472/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4449 - y1_output_loss: 0.1254 - y2_output_loss: 0.3177 - y1_output_root_mean_squared_error: 0.3543 - y2_output_root_mean_squared_error: 0.5651 - val_loss: 0.7882 - val_y1_output_loss: 0.2009 - val_y2_output_loss: 0.5743 - val_y1_output_root_mean_squared_error: 0.4529 - val_y2_output_root_mean_squared_error: 0.7636
# Epoch 473/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3470 - y1_output_loss: 0.1018 - y2_output_loss: 0.2438 - y1_output_root_mean_squared_error: 0.3189 - y2_output_root_mean_squared_error: 0.4953 - val_loss: 0.9503 - val_y1_output_loss: 0.2370 - val_y2_output_loss: 0.6838 - val_y1_output_root_mean_squared_error: 0.4949 - val_y2_output_root_mean_squared_error: 0.8398
# Epoch 474/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3891 - y1_output_loss: 0.1050 - y2_output_loss: 0.2850 - y1_output_root_mean_squared_error: 0.3234 - y2_output_root_mean_squared_error: 0.5333 - val_loss: 0.7999 - val_y1_output_loss: 0.2479 - val_y2_output_loss: 0.5306 - val_y1_output_root_mean_squared_error: 0.5046 - val_y2_output_root_mean_squared_error: 0.7384
# Epoch 475/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.5742 - y1_output_loss: 0.1237 - y2_output_loss: 0.5125 - y1_output_root_mean_squared_error: 0.3514 - y2_output_root_mean_squared_error: 0.6714 - val_loss: 8.5980 - val_y1_output_loss: 0.4905 - val_y2_output_loss: 7.9688 - val_y1_output_root_mean_squared_error: 0.7079 - val_y2_output_root_mean_squared_error: 2.8455
# Epoch 476/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.6589 - y1_output_loss: 0.1446 - y2_output_loss: 0.5135 - y1_output_root_mean_squared_error: 0.3812 - y2_output_root_mean_squared_error: 0.7166 - val_loss: 1.3351 - val_y1_output_loss: 0.2307 - val_y2_output_loss: 1.0685 - val_y1_output_root_mean_squared_error: 0.4865 - val_y2_output_root_mean_squared_error: 1.0481
# Epoch 477/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4302 - y1_output_loss: 0.1216 - y2_output_loss: 0.3070 - y1_output_root_mean_squared_error: 0.3493 - y2_output_root_mean_squared_error: 0.5552 - val_loss: 0.8231 - val_y1_output_loss: 0.1974 - val_y2_output_loss: 0.6209 - val_y1_output_root_mean_squared_error: 0.4503 - val_y2_output_root_mean_squared_error: 0.7876
# Epoch 478/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3685 - y1_output_loss: 0.0991 - y2_output_loss: 0.2680 - y1_output_root_mean_squared_error: 0.3146 - y2_output_root_mean_squared_error: 0.5191 - val_loss: 0.8346 - val_y1_output_loss: 0.2296 - val_y2_output_loss: 0.5880 - val_y1_output_root_mean_squared_error: 0.4860 - val_y2_output_root_mean_squared_error: 0.7735
# Epoch 479/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5122 - y1_output_loss: 0.1266 - y2_output_loss: 0.3863 - y1_output_root_mean_squared_error: 0.3556 - y2_output_root_mean_squared_error: 0.6211 - val_loss: 2.6147 - val_y1_output_loss: 0.7641 - val_y2_output_loss: 1.8326 - val_y1_output_root_mean_squared_error: 0.8795 - val_y2_output_root_mean_squared_error: 1.3569
# Epoch 480/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4309 - y1_output_loss: 0.1118 - y2_output_loss: 0.3163 - y1_output_root_mean_squared_error: 0.3353 - y2_output_root_mean_squared_error: 0.5643 - val_loss: 0.7391 - val_y1_output_loss: 0.1833 - val_y2_output_loss: 0.5463 - val_y1_output_root_mean_squared_error: 0.4324 - val_y2_output_root_mean_squared_error: 0.7431
# Epoch 481/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.6280 - y1_output_loss: 0.1562 - y2_output_loss: 0.4689 - y1_output_root_mean_squared_error: 0.3965 - y2_output_root_mean_squared_error: 0.6862 - val_loss: 0.7080 - val_y1_output_loss: 0.1892 - val_y2_output_loss: 0.4981 - val_y1_output_root_mean_squared_error: 0.4415 - val_y2_output_root_mean_squared_error: 0.7163
# Epoch 482/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3325 - y1_output_loss: 0.1008 - y2_output_loss: 0.2309 - y1_output_root_mean_squared_error: 0.3173 - y2_output_root_mean_squared_error: 0.4815 - val_loss: 1.3415 - val_y1_output_loss: 0.4776 - val_y2_output_loss: 0.8350 - val_y1_output_root_mean_squared_error: 0.7020 - val_y2_output_root_mean_squared_error: 0.9212
# Epoch 483/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3813 - y1_output_loss: 0.1135 - y2_output_loss: 0.2721 - y1_output_root_mean_squared_error: 0.3368 - y2_output_root_mean_squared_error: 0.5175 - val_loss: 1.9647 - val_y1_output_loss: 0.4672 - val_y2_output_loss: 1.4353 - val_y1_output_root_mean_squared_error: 0.6952 - val_y2_output_root_mean_squared_error: 1.2172
# Epoch 484/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5317 - y1_output_loss: 0.1411 - y2_output_loss: 0.3908 - y1_output_root_mean_squared_error: 0.3741 - y2_output_root_mean_squared_error: 0.6259 - val_loss: 0.8640 - val_y1_output_loss: 0.2380 - val_y2_output_loss: 0.6133 - val_y1_output_root_mean_squared_error: 0.4935 - val_y2_output_root_mean_squared_error: 0.7877
# Epoch 485/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4332 - y1_output_loss: 0.1340 - y2_output_loss: 0.2969 - y1_output_root_mean_squared_error: 0.3668 - y2_output_root_mean_squared_error: 0.5464 - val_loss: 1.2082 - val_y1_output_loss: 0.2475 - val_y2_output_loss: 0.9782 - val_y1_output_root_mean_squared_error: 0.5010 - val_y2_output_root_mean_squared_error: 0.9784
# Epoch 486/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3498 - y1_output_loss: 0.1106 - y2_output_loss: 0.2404 - y1_output_root_mean_squared_error: 0.3325 - y2_output_root_mean_squared_error: 0.4891 - val_loss: 1.3793 - val_y1_output_loss: 0.3640 - val_y2_output_loss: 1.0357 - val_y1_output_root_mean_squared_error: 0.6002 - val_y2_output_root_mean_squared_error: 1.0095
# Epoch 487/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4643 - y1_output_loss: 0.1128 - y2_output_loss: 0.3515 - y1_output_root_mean_squared_error: 0.3372 - y2_output_root_mean_squared_error: 0.5921 - val_loss: 1.4089 - val_y1_output_loss: 0.3340 - val_y2_output_loss: 1.0282 - val_y1_output_root_mean_squared_error: 0.5888 - val_y2_output_root_mean_squared_error: 1.0306
# Epoch 488/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.6328 - y1_output_loss: 0.1414 - y2_output_loss: 0.4870 - y1_output_root_mean_squared_error: 0.3766 - y2_output_root_mean_squared_error: 0.7007 - val_loss: 0.8302 - val_y1_output_loss: 0.2318 - val_y2_output_loss: 0.5830 - val_y1_output_root_mean_squared_error: 0.4902 - val_y2_output_root_mean_squared_error: 0.7681
# Epoch 489/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4260 - y1_output_loss: 0.1152 - y2_output_loss: 0.3218 - y1_output_root_mean_squared_error: 0.3328 - y2_output_root_mean_squared_error: 0.5615 - val_loss: 1.9728 - val_y1_output_loss: 0.4951 - val_y2_output_loss: 1.5115 - val_y1_output_root_mean_squared_error: 0.7003 - val_y2_output_root_mean_squared_error: 1.2175
# Epoch 490/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4259 - y1_output_loss: 0.1228 - y2_output_loss: 0.3061 - y1_output_root_mean_squared_error: 0.3495 - y2_output_root_mean_squared_error: 0.5512 - val_loss: 1.9671 - val_y1_output_loss: 0.4807 - val_y2_output_loss: 1.4903 - val_y1_output_root_mean_squared_error: 0.6982 - val_y2_output_root_mean_squared_error: 1.2164
# Epoch 491/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.6214 - y1_output_loss: 0.1768 - y2_output_loss: 0.4425 - y1_output_root_mean_squared_error: 0.4208 - y2_output_root_mean_squared_error: 0.6666 - val_loss: 2.0631 - val_y1_output_loss: 0.5590 - val_y2_output_loss: 1.4374 - val_y1_output_root_mean_squared_error: 0.7611 - val_y2_output_root_mean_squared_error: 1.2181
# Epoch 492/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3575 - y1_output_loss: 0.1158 - y2_output_loss: 0.2442 - y1_output_root_mean_squared_error: 0.3415 - y2_output_root_mean_squared_error: 0.4908 - val_loss: 0.9594 - val_y1_output_loss: 0.2407 - val_y2_output_loss: 0.6967 - val_y1_output_root_mean_squared_error: 0.4973 - val_y2_output_root_mean_squared_error: 0.8438
# Epoch 493/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3584 - y1_output_loss: 0.1109 - y2_output_loss: 0.2462 - y1_output_root_mean_squared_error: 0.3331 - y2_output_root_mean_squared_error: 0.4975 - val_loss: 0.7531 - val_y1_output_loss: 0.2065 - val_y2_output_loss: 0.5324 - val_y1_output_root_mean_squared_error: 0.4607 - val_y2_output_root_mean_squared_error: 0.7354
# Epoch 494/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3924 - y1_output_loss: 0.1175 - y2_output_loss: 0.2741 - y1_output_root_mean_squared_error: 0.3424 - y2_output_root_mean_squared_error: 0.5246 - val_loss: 0.7169 - val_y1_output_loss: 0.1973 - val_y2_output_loss: 0.5029 - val_y1_output_root_mean_squared_error: 0.4495 - val_y2_output_root_mean_squared_error: 0.7175
# Epoch 495/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4043 - y1_output_loss: 0.1107 - y2_output_loss: 0.2983 - y1_output_root_mean_squared_error: 0.3323 - y2_output_root_mean_squared_error: 0.5421 - val_loss: 1.5881 - val_y1_output_loss: 0.2386 - val_y2_output_loss: 1.3661 - val_y1_output_root_mean_squared_error: 0.4926 - val_y2_output_root_mean_squared_error: 1.1599
# Epoch 496/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3191 - y1_output_loss: 0.0941 - y2_output_loss: 0.2242 - y1_output_root_mean_squared_error: 0.3081 - y2_output_root_mean_squared_error: 0.4734 - val_loss: 1.1189 - val_y1_output_loss: 0.2440 - val_y2_output_loss: 0.8766 - val_y1_output_root_mean_squared_error: 0.4974 - val_y2_output_root_mean_squared_error: 0.9335
# Epoch 497/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3598 - y1_output_loss: 0.1033 - y2_output_loss: 0.2545 - y1_output_root_mean_squared_error: 0.3220 - y2_output_root_mean_squared_error: 0.5061 - val_loss: 0.8017 - val_y1_output_loss: 0.2296 - val_y2_output_loss: 0.5651 - val_y1_output_root_mean_squared_error: 0.4841 - val_y2_output_root_mean_squared_error: 0.7532
# Epoch 498/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4200 - y1_output_loss: 0.1245 - y2_output_loss: 0.2971 - y1_output_root_mean_squared_error: 0.3540 - y2_output_root_mean_squared_error: 0.5429 - val_loss: 1.2828 - val_y1_output_loss: 0.1908 - val_y2_output_loss: 1.1086 - val_y1_output_root_mean_squared_error: 0.4420 - val_y2_output_root_mean_squared_error: 1.0428
# Epoch 499/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4545 - y1_output_loss: 0.1276 - y2_output_loss: 0.3317 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.5713 - val_loss: 1.2595 - val_y1_output_loss: 0.2707 - val_y2_output_loss: 1.0109 - val_y1_output_root_mean_squared_error: 0.5186 - val_y2_output_root_mean_squared_error: 0.9953
# Epoch 500/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3817 - y1_output_loss: 0.1055 - y2_output_loss: 0.2749 - y1_output_root_mean_squared_error: 0.3240 - y2_output_root_mean_squared_error: 0.5260 - val_loss: 0.6720 - val_y1_output_loss: 0.1967 - val_y2_output_loss: 0.4628 - val_y1_output_root_mean_squared_error: 0.4498 - val_y2_output_root_mean_squared_error: 0.6853

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 36us/sample - loss: 0.6720 - y1_output_loss: 0.1991 - y2_output_loss: 0.4644 - y1_output_root_mean_squared_error: 0.4498 - y2_output_root_mean_squared_error: 0.6853
# Loss = 0.6720027559763425, Y1_loss = 0.19911375641822815, Y1_mse = 0.44983693957328796, Y2_loss = 0.46444615721702576, Y2_mse = 0.6853097677230835

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
